# %%
# Import libraries
import pandas as pd
import io

# %% [markdown]
# ***VVVVV Dataset with all labels!!! VVVVV***

# %%
# Upload dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3152babc-7cd5-4ab1-a4ce-0bfe2091c380" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3152babc-7cd5-4ab1-a4ce-0bfe2091c380">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read dataset into a Pandas dataframe
df = pd.read_csv(io.BytesIO(uploaded['crimeReducedColumns.csv']))

# %%
# Display the dataframe
display(df)
# Out:
#         OFFENSE_CODE_GROUP DISTRICT  YEAR  MONTH DAY_OF_WEEK  HOUR
# 0       Disorderly Conduct      E18  2018     10   Wednesday    20
# 1            Property Lost      D14  2018      8    Thursday    20
# 2                    Other       B2  2018     10   Wednesday    19
# 3       Aggravated Assault       A1  2018     10   Wednesday    20
# 4                 Aircraft       A7  2018     10   Wednesday    20
# ...                    ...      ...   ...    ...         ...   ...
# 327815     Warrant Arrests       D4  2016      6      Sunday    17
# 327816            Homicide      E18  2015      7    Thursday    13
# 327817     Warrant Arrests      E18  2015      7    Thursday    13
# 327818     Warrant Arrests      E13  2016      5     Tuesday    19
# 327819     Warrant Arrests       D4  2015      6      Monday     0
#
# [327820 rows x 6 columns]

# %%
# Count occurence of all crimes
df['OFFENSE_CODE_GROUP'].value_counts()
# Out:
# Motor Vehicle Accident Response              38134
# Larceny                                      26670
# Medical Assistance                           24226
# Investigate Person                           19176
# Other                                        18612
#                                              ...
# HUMAN TRAFFICKING                                7
# INVESTIGATE PERSON                               4
# Biological Threat                                2
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE        2
# Burglary - No Property Taken                     2
# Name: OFFENSE_CODE_GROUP, Length: 67, dtype: int64

# %%
# Get top 15 most frequent crimes
n = 15
df['OFFENSE_CODE_GROUP'].value_counts()[:n]#.index.tolist()
# Out:
# Motor Vehicle Accident Response    38134
# Larceny                            26670
# Medical Assistance                 24226
# Investigate Person                 19176
# Other                              18612
# Drug Violation                     17037
# Simple Assault                     16263
# Vandalism                          15810
# Verbal Disputes                    13478
# Towed                              11632
# Investigate Property               11443
# Larceny From Motor Vehicle         11120
# Property Lost                      10077
# Warrant Arrests                     8579
# Aggravated Assault                  8033
# Name: OFFENSE_CODE_GROUP, dtype: int64

# %% [markdown]
# ***^^^^^ Dataset with all lables!!! ^^^^^***

# %% [markdown]
# **Keep**: Investigate Person, Drug violation, simple assault, vandalism, verbal disputes, towed, investigate property, Larceny From Motor Vehicle & Property Lost

# %% [markdown]
# -----------------------------------------

# %%
# Upload reduced dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e79fd00a-2e6f-4335-9030-370e1150d414" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e79fd00a-2e6f-4335-9030-370e1150d414">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read into a Pandas dataframe
df2 = pd.read_csv(io.BytesIO(uploaded['crimeReducedLabels.csv']))

# %%
# Display the dataframe
display(df2)
# Out:
#                           OFFENSE_GROUP DISTRICT  YEAR  MONTH        DAY  HOUR
# 0                             Vandalism      C11  2018     10    Tuesday    20
# 1       Motor Vehicle Accident Response      NaN  2018     10  Wednesday    20
# 2                       Verbal Disputes       B2  2018     10  Wednesday    19
# 3                        Simple Assault      E18  2018     10  Wednesday    19
# 4                                 Towed       D4  2018     10  Wednesday    20
# ...                                 ...      ...   ...    ...        ...   ...
# 193868                   Simple Assault       B2  2015     10     Friday    21
# 193869                          Larceny       D4  2016      6     Sunday    17
# 193870                   Drug Violation       A1  2015      8  Wednesday    12
# 193871                   Drug Violation       A1  2015      8  Wednesday    12
# 193872                   Drug Violation      E13  2018      1   Saturday    14
#
# ...

# %%
#  Count the number of null values per column
df2.isnull().sum()
# Out:
# OFFENSE_GROUP       0
# DISTRICT         1105
# YEAR                0
# MONTH               0
# DAY                 0
# HOUR                0
# dtype: int64

# %%
# Remove rows containing null values, then count total of null values
df2_noNAN = df2.dropna()
df2_noNAN.isnull().sum()
# Out:
# OFFENSE_GROUP    0
# DISTRICT         0
# YEAR             0
# MONTH            0
# DAY              0
# HOUR             0
# dtype: int64

# %%
# Group the new dataframe by the classes
df2_noNAN.groupby("OFFENSE_GROUP").count()
# Out:
#                                  DISTRICT   YEAR  MONTH    DAY   HOUR
# OFFENSE_GROUP
# Drug Violation                      16870  16870  16870  16870  16870
# INVESTIGATE PERSON                      4      4      4      4      4
# Investigate Person                  19102  19102  19102  19102  19102
# Investigate Property                11354  11354  11354  11354  11354
# Larceny                             26590  26590  26590  26590  26590
# Medical Assistance                  24159  24159  24159  24159  24159
# Motor Vehicle Accident Response     37672  37672  37672  37672  37672
# Simple Assault                      16223  16223  16223  16223  16223
# Towed                               11568  11568  11568  11568  11568
# Vandalism                           15761  15761  15761  15761  15761
# Verbal Disputes                     13465  13465  13465  13465  13465

# %%
# Rename the erronous class and display the correction
df2NoError = df2_noNAN.replace({"INVESTIGATE PERSON":"Investigate Person"})
df2NoError.groupby("OFFENSE_GROUP").count()
# Out:
#                                  DISTRICT   YEAR  MONTH    DAY   HOUR
# OFFENSE_GROUP
# Drug Violation                      16870  16870  16870  16870  16870
# Investigate Person                  19106  19106  19106  19106  19106
# Investigate Property                11354  11354  11354  11354  11354
# Larceny                             26590  26590  26590  26590  26590
# Medical Assistance                  24159  24159  24159  24159  24159
# Motor Vehicle Accident Response     37672  37672  37672  37672  37672
# Simple Assault                      16223  16223  16223  16223  16223
# Towed                               11568  11568  11568  11568  11568
# Vandalism                           15761  15761  15761  15761  15761
# Verbal Disputes                     13465  13465  13465  13465  13465

# %% [markdown]
# **Save "df2NoError" as a csv to drive**

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
df2NoError.to_csv('crimeNoError2.csv')
# !cp crimeNoError2.csv "drive/My Drive/"
